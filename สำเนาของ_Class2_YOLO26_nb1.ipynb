# %% [markdown]
# <a href="https://colab.research.google.com/github/wpanyasuphakul-png/EXIM_ComputerVision/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_Class2_YOLO26_nb1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPU Utilization (Optional)

# %%
# !nvidia-smi
# Out:
# Sun Jun 21 13:04:59 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# # Check current path (Optional)

# %%
import os
path = os.getcwd()
print(path)
# Out:
# /content

# %% [markdown]
# # Dowload Image and Video
#
#
# *   Image: Download from this link --> https://drive.google.com/drive/folders/1bEVa7NFKEyxpRYyUNDyw9aHAmI2wV0c8?usp=sharing
#
# *   Video: Download from this link --> https://drive.google.com/drive/folders/1cSafpPT69CfMGYWFV220mXJK_4__tnLf?usp=sharing

# %% [markdown]
# #Create new folder
#
#
# Click Right at content(folder) --> New folder
#
#
# *   Image
# *   VDO

# %% [markdown]
# # Install YOLO model from Ultralytics
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/requirements.txt) and check software and hardware.
#
# Model detail: https://github.com/ultralytics/ultralytics

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.1/112.6 GB disk)

# %%
#import torch

# %% [markdown]
# # YOLO26 Model
#
#
# https://docs.ultralytics.com/tasks

# %% [markdown]
# ## Predict (Classification)

# %%
# Run inference on an image with YOLO26n-cls
# !yolo classify predict model=yolo26n-cls.pt source='/content/Image/road.jpg'
# Out:
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n-cls summary (fused): 81 layers, 2,807,024 parameters, 0 gradients, 4.2 GFLOPs
#
# image 1/1 /content/Image/road.jpg: 224x224 cab 0.79, police_van 0.09, racer 0.06, tow_truck 0.03, sports_car 0.01, 4.4ms
# Speed: 170.0ms preprocess, 4.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict-7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Run inference on an image with YOLO26x-cls
# !yolo classify predict model=yolo26x-cls.pt source='/content/Image/road.jpg'
# Out:
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26x-cls summary (fused): 167 layers, 29,613,416 parameters, 0 gradients, 111.3 GFLOPs
#
# image 1/1 /content/Image/road.jpg: 224x224 cab 0.99, police_van 0.01, racer 0.00, sports_car 0.00, passenger_car 0.00, 14.3ms
# Speed: 166.2ms preprocess, 14.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict-8
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## Predict (Detection)

# %% [markdown]
# ###Image

# %%
# Run inference on an image with YOLO26n
# !yolo detect predict model=yolo26n.pt source='/content/Image/road.jpg' conf=0.25
# Out:
# ...
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# image 1/1 /content/Image/road.jpg: 640x480 3 persons, 1 car, 1 traffic light, 56.9ms
# Speed: 4.4ms preprocess, 56.9ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict-2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Run inference on an image with YOLO26x
# !yolo detect predict model=yolo26x.pt source='/content/Image/road.jpg' conf=0.25
# Out:
# ...
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11x summary (fused): 190 layers, 56,919,424 parameters, 0 gradients, 194.9 GFLOPs
#
# image 1/1 /content/Image/road.jpg: 640x480 13 persons, 1 car, 4 traffic lights, 81.5ms
# Speed: 3.4ms preprocess, 81.5ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ###VDO

# %%
# Run inference on an VDO with YOLO26s
# !yolo detect predict model=yolo26s.pt source='/content/VDO/VDO1.mp4' conf=0.25
# Out:
# ...
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26m summary (fused): 132 layers, 20,411,132 parameters, 0 gradients, 68.2 GFLOPs
#
# video 1/1 (frame 1/327) /content/VDO/VDO1.mp4: 384x640 5 persons, 7 cars, 1 motorcycle, 3 buss, 1 truck, 1 backpack, 71.3ms
# video 1/1 (frame 2/327) /content/VDO/VDO1.mp4: 384x640 5 persons, 1 bicycle, 8 cars, 1 motorcycle, 3 buss, 1 backpack, 24.9ms
# video 1/1 (frame 3/327) /content/VDO/VDO1.mp4: 384x640 5 persons, 1 bicycle, 11 cars, 1 motorcycle, 3 buss, 2 trucks, 1 backpack, 24.9ms
# video 1/1 (frame 4/327) /content/VDO/VDO1.mp4: 384x640 5 persons, 1 bicycle, 8 cars, 2 motorcycles, 2 buss, 1 truck, 1 backpack, 24.9ms
# video 1/1 (frame 5/327) /content/VDO/VDO1.mp4: 384x640 5 persons, 2 bicycles, 8 cars, 2 motorcycles, 2 buss, 2 trucks, 1 backpack, 24.9ms
# ...

# %% [markdown]
# ###Display VDO output (Optional for Colab Only)
# Note: Displaying an AVI video file in Google Colab requires a few steps, as Colab's native video player primarily supports the MP4 format. Therefore, you might need to convert the AVI file to MP4.

# %%
#Import dependency for displaying mp4 file
from IPython.display import HTML
from base64 import b64encode

# %%
#Convert avi fil to mp4
#!ffmpeg -i input_path output_path
# !ffmpeg -i "/content/runs/detect/predict3/VDO1.avi" -c:v hevc_nvenc -b:v 2M "/content/runs/detect/predict3/VDO1.mp4"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
mp4 = open('/content/runs/detect/predict3/VDO1.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video controls style="width: 800px; height: 450px;">
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# ## Predict (Segmentation)

# %% [markdown]
# ###Image

# %%
# Run inference on an image with YOLO26m-seg
# !yolo segment predict model=yolo26m-seg.pt source='/content/Image/road.jpg'
# Out:
# ...
# Ultralytics 8.3.229 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n-seg summary (fused): 113 layers, 2,868,664 parameters, 0 gradients, 9.7 GFLOPs
#
# image 1/1 /content/Image/road.jpg: 640x480 5 persons, 1 car, 3 traffic lights, 60.2ms
# Speed: 4.4ms preprocess, 60.2ms inference, 17.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Run inference on an VDO with YOLO26l-seg
# !yolo segment predict model=yolo26l-seg.pt source='/content/Image/road.jpg'

# %% [markdown]
# ### VDO

# %%
# Run inference on an VDO with YOLO26n-seg
# !yolo segment predict model=yolo26n-seg.pt source='/content/VDO/VDO1.mp4'
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11x-seg summary (fused): 203 layers, 62,094,528 parameters, 0 gradients, 296.4 GFLOPs
#
# video 1/1 (frame 1/529) /content/VDO/London.mp4: 384x640 17 persons, 2 cars, 1 truck, 2 traffic lights, 77.1ms
# video 1/1 (frame 2/529) /content/VDO/London.mp4: 384x640 16 persons, 1 car, 1 truck, 2 traffic lights, 40.3ms
# video 1/1 (frame 3/529) /content/VDO/London.mp4: 384x640 17 persons, 1 car, 1 truck, 2 traffic lights, 40.2ms
# video 1/1 (frame 4/529) /content/VDO/London.mp4: 384x640 18 persons, 1 car, 1 truck, 2 traffic lights, 35.9ms
# video 1/1 (frame 5/529) /content/VDO/London.mp4: 384x640 17 persons, 2 cars, 1 truck, 2 traffic lights, 36.7ms
# video 1/1 (frame 6/529) /content/VDO/London.mp4: 384x640 15 persons, 1 car, 1 truck, 2 traffic lights, 36.8ms
# video 1/1 (frame 7/529) /content/VDO/London.mp4: 384x640 14 persons, 1 car, 2 trucks, 2 traffic lights, 35.9ms
# ...

# %% [markdown]
# ## Predict (Pose Estimation)
#
# Upload your VDO and predict with pose estimation model

# %%
# Predict pose with YOLO26n-pose.pt
# !yolo pose predict model=yolo26n-pose.pt source='/content/Image/img_lisa.jpeg' # predict with official model
# Out:
# ...
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n-pose summary (fused): 132 layers, 2,926,494 parameters, 0 gradients, 7.5 GFLOPs
#
# image 1/1 /content/Image/img_lisa.jpeg: 640x544 1 person, 98.6ms
# Speed: 15.7ms preprocess, 98.6ms inference, 35.1ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to /content/runs/pose/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Resource
#
# YOLO26: https://www.ultralytics.com/blog/ultralytics-yolo26-the-new-standard-for-edge-first-vision-ai#ultralytics-yolo26-sets-a-new-standard-for-vision-ai
